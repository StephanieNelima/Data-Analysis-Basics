# %%
import pandas as pd

# %%
people={"first":["jane","john","joseph"],"last":["doe","doe","carpt"],"email":["jane@gmail.com","john@gmail.com","jo@gmail.com"]}
people
# Out:
# {'first': ['jane', 'john', 'joseph'],
#  'last': ['doe', 'doe', 'carpt'],
#  'email': ['jane@gmail.com', 'john@gmail.com', 'jo@gmail.com']}

# %%
peopleDf=pd.DataFrame(people)
peopleDf
# Out:
#     first   last           email
# 0    jane    doe  jane@gmail.com
# 1    john    doe  john@gmail.com
# 2  joseph  carpt    jo@gmail.com

# %%
peopleDf.sort_values(by='last')
# Out:
#     first   last           email
# 2  joseph  carpt    jo@gmail.com
# 0    jane    doe  jane@gmail.com
# 1    john    doe  john@gmail.com

# %%
peopleDf.sort_values(by='last', ascending=False)
# Out:
#     first   last           email
# 0    jane    doe  jane@gmail.com
# 1    john    doe  john@gmail.com
# 2  joseph  carpt    jo@gmail.com

# %%
peopleDf.sort_values(by=["last","first"], ascending=False)
# Out:
#     first   last           email
# 1    john    doe  john@gmail.com
# 0    jane    doe  jane@gmail.com
# 2  joseph  carpt    jo@gmail.com

# %%
peopleDf.sort_values(by=['last','first'], ascending=[True,False])
# Out:
#     first   last           email
# 2  joseph  carpt    jo@gmail.com
# 1    john    doe  john@gmail.com
# 0    jane    doe  jane@gmail.com

# %%
peopleDf.sort_index()
# Out:
#     first   last           email
# 0    jane    doe  jane@gmail.com
# 1    john    doe  john@gmail.com
# 2  joseph  carpt    jo@gmail.com

# %%
peopleDf['last'].sort_values()
# Out:
# 2    carpt
# 0      doe
# 1      doe
# Name: last, dtype: object

# %%
df2=pd.read_csv("survey_results_schema.csv")
df3=pd.read_csv("survey_results_public.csv")
df3.head(50)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# 5            6  I am not primarily a developer, but I write co...
# 6            7                        I code primarily as a hobby
# 7            8                     I am a developer by profession
# 8            9                     I am a developer by profession
# 9           10                     I am a developer by profession
# 10          11                     I am a developer by profession
# 11          12  I am not primarily a developer, but I write co...
# 12          13                     I am a developer by profession
# ...

# %%
df3.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df3.sort_values(by='Country',inplace=True)

# %%
df3['Country'].head(10)
# Out:
# 51188    Afghanistan
# 38512    Afghanistan
# 7944     Afghanistan
# 29704    Afghanistan
# 19201    Afghanistan
# 24812    Afghanistan
# 56355    Afghanistan
# 2737     Afghanistan
# 56266    Afghanistan
# 56188    Afghanistan
# Name: Country, dtype: object

# %%
df3[['Country','ConvertedCompYearly']].head(50)
# Out:
#            Country  ConvertedCompYearly
# 51188  Afghanistan                  NaN
# 38512  Afghanistan             158484.0
# 7944   Afghanistan                  NaN
# 29704  Afghanistan                  NaN
# 19201  Afghanistan                  NaN
# 24812  Afghanistan                  NaN
# 56355  Afghanistan                  NaN
# 2737   Afghanistan                  NaN
# 56266  Afghanistan                  NaN
# 56188  Afghanistan                  NaN
# 69586  Afghanistan                  NaN
# 2448   Afghanistan              10894.0
# 5464   Afghanistan                  NaN
# 43690  Afghanistan              13212.0
# 30040  Afghanistan                  NaN
# 43639  Afghanistan              92448.0
# 17038  Afghanistan                  NaN
# 28582  Afghanistan                  NaN
# 28434  Afghanistan                  NaN
# 64906  Afghanistan                  NaN
# 8890   Afghanistan                  NaN
# 6891   Afghanistan              15600.0
# ...

# %%
df3.sort_values(by=['ConvertedCompYearly','Country'],ascending=False,inplace=True)

# %%
df3[['ConvertedCompYearly','Country']].head(50)
# Out:
#        ConvertedCompYearly                                            Country
# 40304           50000000.0  United Kingdom of Great Britain and Northern I...
# 201             44790396.0                                           Portugal
# 62026           35000000.0                           United States of America
# 70522           32500000.0                           United States of America
# 61043           28853768.0                                           Thailand
# 18922           22500000.0                           United States of America
# 62223           22500000.0                           United States of America
# 66495           18000000.0                           United States of America
# 1290            15000000.0                           United States of America
# 24163           15000000.0                           United States of America
# 47933           14250000.0                           United States of America
# ...

# %%
df3['ConvertedCompYearly'].nlargest(10)
# Out:
# 40304    50000000.0
# 201      44790396.0
# 62026    35000000.0
# 70522    32500000.0
# 61043    28853768.0
# 18922    22500000.0
# 62223    22500000.0
# 66495    18000000.0
# 1290     15000000.0
# 24163    15000000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
 df3.nlargest(10,'ConvertedCompYearly')
# Out:
#        ResponseId                      MainBranch  \
# 40304       40305  I am a developer by profession
# 201           202  I am a developer by profession
# 62026       62027  I am a developer by profession
# 70522       70523  I am a developer by profession
# 61043       61044  I am a developer by profession
# 18922       18923  I am a developer by profession
# 62223       62224  I am a developer by profession
# 66495       66496  I am a developer by profession
# 1290         1291  I am a developer by profession
# 24163       24164  I am a developer by profession
#
#                                               Employment  \
# 40304  Independent contractor, freelancer, or self-em...
# 201                                  Employed, full-time
# 62026                                Employed, full-time
# 70522  Independent contractor, freelancer, or self-em...
# 61043                                I prefer not to say
# 18922                                Employed, full-time
# ...
