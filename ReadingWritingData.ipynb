# %%
import pandas as pd

# %%
#reading a csv to df index_col='Respondent'
srDf=pd.read_csv('survey_results_public.csv',index_col='ResponseId')
schemaDf=pd.read_csv('survey_results_schema.csv', index_col='qid')

# %%
schemaDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, QID16 to QID294
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qname       79 non-null     object
#  1   question    79 non-null     object
#  2   force_resp  66 non-null     object
#  3   type        79 non-null     object
#  4   selector    79 non-null     object
# dtypes: object(5)
# memory usage: 3.7+ KB

# %%
filt=(srDf['Country']=='India')
indiaDf=srDf.loc[filt]

# %%
indiaDf.to_csv('India.csv')

# %%
#to tsv
indiaDf.to_csv('India.tsv', sep='\t')

# %%
#to excel
indiaDf.to_excel('InDf.xlsx')

# %%
xlDf=pd.read_excel('InDf.xlsx')

# %%
indiaDf.to_json('inDf.json', orient='records')

# %%
jsonDf=pd.read_json('inDf.json',orient='records')
jsonDf
# Out:
#                                              MainBranch  \
# 0                           I code primarily as a hobby
# 1                        I am a developer by profession
# 2                        I am a developer by profession
# 3                        I am a developer by profession
# 4                        I am a developer by profession
# ...                                                 ...
# 6634                     I am a developer by profession
# 6635  I used to be a developer by profession, but no...
# 6636                     I am a developer by profession
# 6637                              I am learning to code
# 6638                     I am a developer by profession
#
#                               Employment  \
# 0                     Student, part-time
# 1     Not employed, but looking for work
# 2                    Employed, full-time
# 3                    Employed, full-time
# 4                    Employed, full-time
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine= create_engine('postgresql://thisuser:pass123@localhost:7882/this_sampledb')

# %%
 indiaDf.to_sql('this_table',engine,if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3279 """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281 The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299 """
# -> 3300 return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
# ...

# %%
sqlDf=pd.read_sql('this_df',engine)

# %%
queryDf=pd.read_sql_query('SELECT * FROM this_table',engine,index_col='Respondent ')

# %%
postsDf=pd.read_json('https://github.com/CoreyMSchafer/code_snippets/blob/master/Python-JSON/new_states.json')
# Out:
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:591, in HTTPResponse._read_chunked(self, amt)
#     589     break
# --> 591 value.append(self._safe_read(chunk_left))
#     592 if amt is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:632, in HTTPResponse._safe_read(self, amt)
#     631 if len(data) < amt:
# --> 632     raise IncompleteRead(data, amt-len(data))
#     633 return data
#
# IncompleteRead: IncompleteRead(15064 bytes read, 8309 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 postsDf=pd.read_json('https://github.com/CoreyMSchafer/code_snippets/blob/master/Python-JSON/new_states.json')
#
# ...
